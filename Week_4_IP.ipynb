# %% [markdown]
# <a href="https://colab.research.google.com/github/LKabaya/Moringa_Prep_Week4_IP/blob/master/Week_4_IP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import pandas as pd
import pandas_profiling
import numpy as np

# %%
#loading our dataset

url= 'http://bit.ly/Autolibdataset'

auto_lib= pd.read_csv(url)

# %%
# previewing our dataset
auto_lib.head()
# Out:
#    Unnamed: 0                     Address  Cars  ...  day  hour  minute
# 0           0              24 Rue Vulpian     3  ...    1     0       0
# 1           1  8 Boulevard Richard Lenoir     0  ...    1     0       0
# 2           2        4 Rue Charles Bossut     3  ...    1     0       0
# 3           3   3 avenue Claude Vellefaux     4  ...    1     0       0
# 4           4      236 Boulevard Voltaire     1  ...    1     0       0
#
# [5 rows x 26 columns]

# %%
#descriptive statistics
profile=pandas_profiling.ProfileReport(auto_lib)
profile_to.html('autolib.html' )
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>26 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>14421829 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>7.6% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>2.8 GiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>208.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>10 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>13 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Address"><code>Address</code></a> has a high cardinality: 1118 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Bluecar counter"><code>Bluecar counter</code></a> is highly correlated with <a href="#pp_var_Cars"><code>Cars</code></a> (ρ = 1) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_Cars"><code>Cars</code></a> has 4188686 / 29.0% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Charge Slots"><code>Charge Slots</code></a> has 11646717 / 80.8% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_City"><code>City</code></a> has a high cardinality: 88 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Displayed comment"><code>Displayed comment</code></a> has 14099610 / 97.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Geo point"><code>Geo point</code></a> has a high cardinality: 1119 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_ID"><code>ID</code></a> has a high cardinality: 1119 distinct values  <span class="label label-warning">Warning</span

# %%
#Check for completeness: missing values
auto_lib.isnull().sum()

# %%
#Data Cleaning:drop duplicated rows:
auto_lib[auto_lib.duplicated(subset=None, keep= 'first')]

# %%
#Data Cleaning:
#Validity
#Drop unnecessary columns not needed to anser our questions

auto_lib.drop(['Address','Bluecar counter','Charge Slots', 'Charging Status','Public name','Displayed comment','Scheduled at', 'Subscription status','Station type','Geo point'], axis=1, inplace=True)

# %%
#check for accuracy: Remove outliers
Q1= auto_lib.quantile(0.25)
Q3= auto_lib.quantile(0.75)
IQR= Q3-Q1
auto_lib= auto_lib[~((auto_lib < (Q1- 1.5*IQR))|(auto_lib > (Q3 + 1.5*IQR))).any(axis=1)]

# %%
#SAVING THE CLEAN DATASET AS CSV
auto_lib.to_csv('auto_cars.csv')

# %%
# loading our clean dataset
auto_car= pd.read_csv('/content/auto_cars.csv', index_col = 0)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
auto_car.head()
# Out:
#    Unnamed: 0.1  Cars  Utilib counter  ...  day hour minute
# 1             1     0               0  ...    1    0      0
# 2             2     3               0  ...    1    0      0
# 3             3     4               0  ...    1    0      0
# 4             4     1               0  ...    1    0      0
# 5             5     1               0  ...    1    0      0
#
# [5 rows x 16 columns]

# %%
#Answering our questions:
#1. What was the most popular hour of the day for picking up a shared electric car (Bluecar) 
#in the city of Paris over the month of April 2018?
# select city as Paris
paris= auto_car.copy()

paris.drop(paris[paris.City != 'Paris'].index, inplace=True)

# %%
#sort the data by station and hour 
paris.sort_values(['ID','day','hour','minute'], ascending=True, inplace=True)
paris.head(20)
# Out:
#        Unnamed: 0.1  Cars  Utilib counter  ...  day hour minute
# 140             140     1               0  ...    1    0      0
# 1275            136     1               0  ...    1    0      1
# 2392            134     1               0  ...    1    0      2
# 3538            136     1               0  ...    1    0      3
# 4656            135     1               0  ...    1    0      4
# 5799            137     1               0  ...    1    0      5
# 6918            137     1               0  ...    1    0      6
# 8374            451     0               0  ...    1    0      7
# 9492            450     0               0  ...    1    0      8
# 10628           447     0               0  ...    1    0      9
# 11334            34     0               0  ...    1    0     10
# 12419            34     0               0  ...    1    0     10
# 12477            34     0               0  ...    1    0     11
# 13596            34     0               0  ...    1    0     12
# 14738            33     0               0  ...    1    0     13
# 15856            32     0               0  ...    1    0     14
# 16995            32     0               0  ...    1    0     15
# 18117            35     0               0  ...    1    0     16
# 19257            35     0               0  ...    1    0     17
# 20377            36     0               0  ...    1    0     18
#
# [20 rows x 16 columns]

# %%
#Picking up= negative change in cars at station 

#create column with rate of change of cars per minute 
paris['change']= paris['Cars'].diff()

# %%
#Determine hour with the highest rate of negative change in cars
paris1= paris[paris.change < 0]
paris1.groupby(['hour'])['change'].sum().sort_values(ascending=True)
#most popular hour is hour 19, with total pickups of 5534 cars in the period of April 1- Apil 9
# Out:
# hour
# 19   -5534.0
# 18   -5370.0
# 17   -4819.0
# 20   -4649.0
# 16   -4462.0
# 15   -4147.0
# 12   -3971.0
# 14   -3753.0
# 13   -3707.0
# 21   -3569.0
# 22   -3559.0
# 11   -3527.0
# 9    -2883.0
# 8    -2858.0
# 10   -2810.0
# 23   -2781.0
# 0    -2684.0
# 7    -1806.0
# 2    -1516.0
# 1    -1495.0
# 6     -697.0
# 3     -633.0
# 5     -587.0
# 4     -569.0
# Name: change, dtype: float64

# %%
#Q2What is the most popular hour for returning cars?

#sort the dataset(all cities) by station and hour 
auto_car.sort_values(['ID','day','hour','minute'], ascending=True, inplace=True)
auto_car.head()
# Out:
#       Unnamed: 0.1  Cars  Utilib counter  ...  day hour minute
# 750            750     0               0  ...    1    0      0
# 1892           753     0               0  ...    1    0      1
# 3011           753     0               0  ...    1    0      2
# 4153           751     0               0  ...    1    0      3
# 5274           753     0               0  ...    1    0      4
#
# [5 rows x 16 columns]

# %%
#create column with rate of change of cars per minute 
auto_car['change']= auto_car['Cars'].diff()

# %%
#Returns result in increase of cars at the station therefore:
# Determine hour with the highest rate of positive change in cars
auto_car= auto_car[auto_car.change > 0]
returns = auto_car.groupby(['hour'])['change'].sum().sort_values(ascending=False)
returns
#Hour 20 has the highest rate of returns at 8565
# Out:
# hour
# 20    8565.0
# 19    8332.0
# 18    7483.0
# 17    6772.0
# 21    6444.0
# 16    6167.0
# 13    5913.0
# 15    5662.0
# 14    5531.0
# 12    5502.0
# 22    5045.0
# 9     4933.0
# 11    4573.0
# 10    4571.0
# 0     4460.0
# 23    4299.0
# 8     3601.0
# 2     2639.0
# 1     2527.0
# 7     1824.0
# 6     1310.0
# 5     1127.0
# 3     1022.0
# 4      990.0
# Name: change, dtype: float64

# %%
#Q3:What station is the most popular?
# 3(a) Overall?
#station with most activity whether positive or negative.
station= auto_car[auto_car.change!=0]
station.head()
station.groupby(['ID'])['change'].count().sort_values(ascending=False)
# station with the most activity is paris-portedauteuil-parking which has a frequency of 395
# Out:
# ID
# paris-portedauteuil-parking               395
# levalloisperret-marjolin-parking          265
# neuillysurseine-parmentier-parking        265
# boulognebillancourt-jeanjaures-61         259
# boulognebillancourt-jeanjaures-245        258
# boulognebillancourt-edouardvaillant-81    248
# paris-beaugrenelle-4                      246
# boulognebillancourt-andremorizet-121      229
# paris-pereire-271                         228
# paris-olivierdeserres-3                   225
# paris-raymondlosserand-145                225
# paris-olier-15                            221
# paris-flandre-119                         221
# paris-generalkoenig-12                    219
# paris-concorde-parking                    219
# paris-flandre-169                         218
# paris-ramey-62                            216
# paris-diderot-24                          211
# montrouge-republique-43                   210
# vincennes-degaulle-6                      207
# puteaux-dionbouton-30                     207
# boulognebillancourt-gallieni-114          204
# courbevoie-sebastopol-4                   204
# courbevoie-arche-49                       203
# paris-victoria-17                         203
# boulognebillancourt-sevres-80             203
# paris-saintmartin-243                     201
# paris-fleurus-2                           199
# paris-murat-98                            199
# paris-exelmans-32                         199
#                                          ...
# noisylesec-marcsangnier-8                   1
# alfortville-europe-22                       1
# neuillysurseine-bineau-161                  1
# paris-etoilefoch-parking                    1
# paris-ecoledemedecine-21                    1
# paris-rennesmontparnasse-parking            1
# paris-chapelle-75                           1
# chatenaymalabry-divisionleclerc-81          1
# bagnolet-generaldegaulle-33                 1
# paris-boucry-35                             1
# meudon-marcelallegot-12                     1
# maisonsalfort-generalleclerc-145            1
# paris-voltaire-59                           1
# aulnaysousbois-josephmariejacquard-2        1
# paris-villiot-20                            1
# limeilbrevannes-emilezola-5                 1
# aulnaysousbois-8mai-9                       1
# sucyenbrie-georgespompidou-2                1
# chatillon-liberte-100                       1
# paris-vercingetorix-106                     1
# paris-charleshermite-52                     1
# paris-citroencevennes-parking               1
# bourglareine-leclerc-35                     1
# clichysousbois-11novembre1918-1             1
# paris-crozatier-33                          1
# paris-custine-45                            1
# asnieressurseine-henripoincare-53           1
# paris-saintantoine-16                       1
# issylesmoulineaux-generalleclerc-46         1
# lebourget-anizancavillon-10                 1
# Name: change, Length: 1091, dtype: int64

# %%
# At the most popular picking hour?
#determine most popular picking hour overall

auto_car= auto_car[auto_car.change < 0]
pick= auto_car.groupby(['hour'])['change'].sum().sort_values(ascending=True)
pick
#hour 19 is most popular hour overall
# Out:
# hour
# 19   -8273.0
# 18   -8194.0
# 17   -7549.0
# 20   -6933.0
# 16   -6747.0
# 15   -6148.0
# 12   -6040.0
# 14   -5668.0
# 13   -5560.0
# 11   -5402.0
# 21   -5240.0
# 22   -5017.0
# 9    -4703.0
# 8    -4633.0
# 10   -4459.0
# 0    -3901.0
# 23   -3757.0
# 7    -3091.0
# 1    -1960.0
# 2    -1907.0
# 6    -1417.0
# 5    -1001.0
# 4     -867.0
# 3     -822.0
# Name: change, dtype: float64

# %%
#most popular station at hour 19:
station= auto_car[(auto_car.change!=0) & (auto_car.hour ==19)]
station.head()
station.groupby(['ID'])['change'].count().sort_values(ascending=False)
# station with highest rate of change at hour 19 is boulognebillancourt-jeanjaures-245 with frequency of 32
# Out:
# ID
# boulognebillancourt-jeanjaures-245        32
# paris-beaugrenelle-4                      30
# boulognebillancourt-edouardvaillant-81    28
# boulognebillancourt-jeanjaures-61         25
# paris-ranelagh-10                         24
# boulognebillancourt-gallieni-114          24
# boulognebillancourt-reine-12              24
# boulognebillancourt-andremorizet-121      23
# boulognebillancourt-sevres-80             22
# issylesmoulineaux-gallieni-27             22
# paris-generalkoenig-12                    22
# paris-buissonsaintlouis-2                 22
# paris-jouffroydabbans-108                 21
# paris-portedauteuil-parking               21
# paris-pereire-170                         21
# paris-frigos-24                           20
# courbevoie-arche-49                       20
# paris-reaumur-116                         20
# neuillysurseine-parmentier-parking        20
# paris-conservatoire-13                    20
# paris-pereire-271                         20
# paris-pereire-50                          20
# montrouge-republique-43                   20
# issylesmoulineaux-renejacques-1           19
# issylesmoulineaux-champchardon-44         19
# puteaux-fernandpelloutier-2               19
# paris-cotentin-29                         19
# paris-metz-6                              19
# levalloisperret-marjolin-parking          19
# paris-saintmartin-243                     19
#                                           ..
# rueilmalmaison-charlesdrot-21              1
# rueilmalmaison-boispreau-1                 1
# joinvillelepont-mozart-18                  1
# rosnysousbois-jeanjaures-5                 1
# montfermeil-leclerc-19                     1
# saintdenis-cheminots-24                    1
# montreuil-galilee-29                       1
# montreuil-roches-22                        1
# nogentsurmarne-port-27                     1
# neuillyplaisance-paulcezanne-2             1
# nanterre-waldeckrochet-8                   1
# nanterre-union-13                          1
# champignysurmarne-boislabbe-53             1
# nanterre-salvadorallende-123               1
# nanterre-rigault-1                         1
# nanterre-republique-326                    1
# nanterre-peupliers-13                      1
# nanterre-paulvaillantcouturier-94          1
# chatillon-republique-140                   1
# chaville-anatolefrance-28                  1
# saintouen-edouardvaillant-28               1
# rueilmalmaison-18juin1940-175              1
# clamart-generaldegaulle-118                1
# nanterre-champspierreux-29                 1
# clichylagarenne-claudedebussy-7            1
# nanterre-aimecesaire-5                     1
# colombes-audra-7                           1
# colombes-charlesdegaulle-156               1
# paris-quaidausterlitz-parking              1
# nanterre-lens-13                           1
# Name: change, Length: 1016, dtype: int64

# %%
# What postal code is the most popular for picking up Bluecars? 

code = auto_car[auto_car.change!=0] 
code.groupby(['Postal code'])['change'].count().sort_values(ascending=False)
# The most popular Postal code is 75015 with a frequency of 7366
# Out:
# Postal code
# 75015    7366
# 75016    6324
# 75017    6129
# 75013    4512
# 75019    4110
# 75012    3977
# 75014    3878
# 75020    3870
# 75011    3797
# 75018    3564
# 75008    3477
# 75009    2764
# 75010    2602
# 75005    2593
# 92100    2590
# 75007    2451
# 75006    2336
# 92130    2080
# 75003    2009
# 75004    1635
# 75002    1460
# 92600    1442
# 92300    1344
# 92150    1204
# 92000    1188
# 75001    1171
# 93100    1159
# 92500    1047
# 93400    1016
# 92400     927
#          ...
# 92110     181
# 92380     179
# 95880     176
# 94410     169
# 94150     168
# 93200     154
# 94450     154
# 93800     145
# 93310     133
# 93350     129
# 92340     121
# 92410     112
# 95870     107
# 91330     103
# 92390     103
# 91400     102
# 92420      88
# 93300      81
# 92290      79
# 91370      71
# 75116      62
# 75112      59
# 93150      57
# 92360      47
# 94100      44
# 93440      17
# 93370      17
# 94370       1
# 91570       1
# 93390       1
# Name: change, Length: 106, dtype: int64

# %%
#Does the most popular station belong to that postal code?
# Overall?
auto_car.groupby(['Postal code'])['ID'].sort_values(ascending=False)

# At the most popular picking hour?
# code = auto_car[(auto_car.change!=0) & (auto_car.hour ==19)]
# code.groupby(['Postal code'])['change'].count().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-bc6f8f6af223> in <module>()
# ----> 1 auto_car.groupby(['Postal code'])['ID'].sort_values(ascending=False)
#       2
#       3 # At the most popular picking hour?
#       4 # code = auto_car[(auto_car.change!=0) & (auto_car.hour ==19)]
#       5 # code.groupby(['Postal code'])['change'].count().sort_values(ascending=False)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'sort_values' of 'SeriesGroupBy' objects, try using the 'apply' method
